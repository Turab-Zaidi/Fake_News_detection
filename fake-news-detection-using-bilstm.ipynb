# %%
import pandas as pd
import numpy as np

# %%
fake_news_dataset = pd.read_csv('/kaggle/input/fake-news-detection/fake.csv')
true_news_dataset = pd.read_csv('/kaggle/input/fake-news-detection/true.csv')

# %%
fake_news_dataset.info(),true_news_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB
# (None, None)

# %% [markdown]
# We have a well balanced dataset

# %%
fake_news_dataset.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
true_news_dataset.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
fake_news_dataset.head(3)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017

# %%
fake_news_dataset['subject'].value_counts()
# Out:
# subject
# News               9050
# politics           6841
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: count, dtype: int64

# %%
true_news_dataset['subject'].value_counts()
# Out:
# subject
# politicsNews    11272
# worldnews       10145
# Name: count, dtype: int64

# %% [markdown]
# Since the date column won't help us much and there is great imbalance among the subject in fake news , we will be dropping the subject and date column

# %%
fake_news_dataset.drop(['subject','date'],axis=1,inplace=True)
true_news_dataset.drop(['subject','date'],axis=1,inplace=True)

# %%
fake_news_dataset['value'] = 0
true_news_dataset['value'] = 1

# %%
news_dataset = pd.concat([fake_news_dataset,true_news_dataset ], ignore_index=True)

# %%
news_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   44898 non-null  object
#  1   text    44898 non-null  object
#  2   value   44898 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
news_dataset.sample(5)
# Out:
#                                                    title  \
# 5627    Karma In All Its Glory: Republican Chairwoman...
# 7372    You’re Not Going To Believe What Trump Just S...
# 20077  WATCH: HARRY REID Caught Calling Benghazi Moth...
# 26160  Trump to Republican senators: Don't leave town...
# 19268  HERE’S WHAT Feminists Left Behind After Their ...
#
#                                                     text  value
# 5627   A little over a month ago, Linda Sorenson, the...      0
# 7372   Republican front runner Donald Trump has stopp...      0
# 20077  Harry Reid s disrespectful comments are just a...      0
# 26160  WASHINGTON (Reuters) - U.S. President Donald T...      1
# 19268                                                         0

# %%
news_dataset['Combined_news'] = news_dataset['title'] + news_dataset['text']
news_dataset.drop(['title','text'], inplace = True, axis = 1)

# %%
import re
import spacy
from nltk.corpus import stopwords

nlp = spacy.load("en_core_web_sm")

def preprocessing(data):
    text = []
    stop_words = set(stopwords.words('english'))
    for i in data:
        i = i.lower()
        # get rid of urls
        i = re.sub('https?://\S+|www\.\S+', '', i)
        # get rid of non words and extra spaces
        i = re.sub('\\W', ' ', i)
        i = re.sub('\n', '', i)
        i = re.sub(' +', ' ', i)
        i = re.sub('^ ', '', i)
        i = re.sub(' $', '', i)
        
        # Lemmatization using spaCy
        doc = nlp(i)
        tokens = [token.lemma_ for token in doc if token.text.lower() not in stop_words]
        
        i = ' '.join(tokens)
        
        text.append(i)
        
    return text

news_dataset['preprocessed_news'] = preprocessing(news_dataset['Combined_news'])

# %%
news_dataset
# Out:
#        value                                      Combined_news  \
# 0          0   Donald Trump Sends Out Embarrassing New Year’...
# 1          0   Drunk Bragging Trump Staffer Started Russian ...
# 2          0   Sheriff David Clarke Becomes An Internet Joke...
# 3          0   Trump Is So Obsessed He Even Has Obama’s Name...
# 4          0   Pope Francis Just Called Out Donald Trump Dur...
# ...      ...                                                ...
# 44893      1  'Fully committed' NATO backs new U.S. approach...
# 44894      1  LexisNexis withdrew two products from Chinese ...
# 44895      1  Minsk cultural hub becomes haven from authorit...
# 44896      1  Vatican upbeat on possibility of Pope Francis ...
# 44897      1  Indonesia to buy $1.14 billion worth of Russia...
#
#                                        preprocessed_news
# 0      donald trump send embarrass new year eve messa...
# 1      drunk bragging trump staffer start russian col...
# 2      sheriff david clarke become internet joke thre...
# 3      trump obsessed even obama name code website im...
# 4      pope francis call donald trump christmas speec...
# ...                                                  ...
# 44893  fully commit nato back new u approach afghanis...
# 44894  lexisnexis withdraw two product chinese market...
# 44895  minsk cultural hub become authoritiesminsk reu...
# 44896  vatican upbeat possibility pope francis visit ...
# 44897  indonesia buy 1 14 billion worth russian jetsj...
#
# [44898 rows x 3 columns]

# %%
feature = news_dataset['preprocessed_news']
target = news_dataset['value']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(feature, target, test_size=0.20, random_state=32)

# %%
X_train = [str(text) for text in X_train]
X_test = [str(text) for text in X_test]

from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=7000)

tokenizer.fit_on_texts(X_train)

X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
# Out:
# 2024-03-29 10:16:07.788942: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-29 10:16:07.789067: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-29 10:16:07.920941: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
max_len = max([len(i) for i in X_train ])
max_len
# Out:
# 4487

# %%
import tensorflow as tf
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, padding='post', maxlen=512)
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, padding='post', maxlen=512)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(7000, 128),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), optimizer='adam', metrics=['accuracy'])
model.build(input_shape=(512,1))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (512, 1, 128)          │       896,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (512, 1, 256)          │       263,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (512, 128)             │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (512, 64)              │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (512, 64)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (512, 1)               │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,331,841 (5.08 MB)
#  Trainable params: 1,331,841 (5.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, Y_train, epochs=20,validation_split=0.1, batch_size=30, shuffle=True)
# Out:
# Epoch 1/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 79s 67ms/step - accuracy: 0.9479 - loss: 0.1006 - val_accuracy: 0.9914 - val_loss: 0.0327
# Epoch 2/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9950 - loss: 0.0160 - val_accuracy: 0.9958 - val_loss: 0.0110
# Epoch 3/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9977 - loss: 0.0102 - val_accuracy: 0.9969 - val_loss: 0.0075
# Epoch 4/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9987 - loss: 0.0044 - val_accuracy: 0.9950 - val_loss: 0.0165
# Epoch 5/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 0.9972 - val_loss: 0.0096
# Epoch 6/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 74s 69ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9967 - val_loss: 0.0182
# Epoch 7/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9990 - loss: 0.0032 - val_accuracy: 0.9964 - val_loss: 0.0177
# Epoch 8/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9961 - val_loss: 0.0182
# Epoch 9/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9998 - loss: 6.8007e-04 - val_accuracy: 0.9964 - val_loss: 0.0209
# Epoch 10/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9958 - val_loss: 0.0304
# Epoch 11/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9997 - loss: 0.0020 - val_accuracy: 0.9958 - val_loss: 0.0237
# Epoch 12/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 82s 67ms/step - accuracy: 0.9999 - loss: 3.2720e-04 - val_accuracy: 0.9967 - val_loss: 0.0220
# Epoch 13/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9998 - loss: 6.9277e-04 - val_accuracy: 0.9961 - val_loss: 0.0244
# Epoch 14/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9999 - loss: 2.6712e-04 - val_accuracy: 0.9969 - val_loss: 0.0218
# Epoch 15/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 0.9967 - val_loss: 0.0268
# Epoch 16/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 1.0000 - loss: 8.7540e-06 - val_accuracy: 0.9972 - val_loss: 0.0263
# Epoch 17/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 1.0000 - loss: 4.4904e-06 - val_accuracy: 0.9969 - val_loss: 0.0277
# Epoch 18/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 1.0000 - loss: 3.3439e-06 - val_accuracy: 0.9969 - val_loss: 0.0286
# Epoch 19/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 1.0000 - loss: 1.1234e-06 - val_accuracy: 0.9969 - val_loss: 0.0308
# Epoch 20/20
# 1078/1078 ━━━━━━━━━━━━━━━━━━━━ 72s 67ms/step - accuracy: 1.0000 - loss: 1.6752e-06 - val_accuracy: 0.9969 - val_loss: 0.0341
